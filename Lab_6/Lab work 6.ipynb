# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 6: Basics of data visualization

# %% [markdown]
# ## Lab work 6

# %% [markdown]
# #### Мета:
#
# * навчитися візуалізовувати дані в Python

# %% [markdown]
# ### Завдання:

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
np.random.seed(0)

df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30),
                        'd':np.arange(0, 30)})
df.head()
# Out:
#     a   b   c  d
# 0  44  47  17  0
# 1  47  64  79  1
# 2  64  82   4  2
# 3  67  99  42  3
# 4  67  88  58  4

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %% [markdown]
# # Створити візуалізацію, аналогічно рисунку
#  - перші 3 графіки візуалізувати, викорстовуючи значення із df
#  - останній це пряма пропорційність

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**

# %%
x = np.arange(1, 30)
y = x

fig, ax = plt.subplots(2, 2, figsize=(15, 10))

ax[0][0].plot(df['a'])
ax[0][1].plot(df['b'])
ax[1][0].plot(df['c'])
ax[1][1].plot(x, y)
plt.show()

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**
# - використовуйте колонки `a` та `b`

# %%
fig = plt.subplots(figsize=(15, 10))

ax = plt.plot(df['a'])

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**
# - використовуйте колонки `a` та `b`

# %%
fig = plt.subplots(figsize=(15, 10))

ax = plt.plot(df['a'])
ax = plt.plot(df['b'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`
# - задайте стиль 'darkgrid' за допомогою команди `sns.set_style`

# %%
plt.figure(figsize=(15,10)) 
sns.set_style("darkgrid")

ax = plt.plot(df['a'])
ax = plt.plot(df['b'])

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**
# - для колонки `a` використайте червоний колір та лінію формату `-.`
#
# - для колонки `b` використайте помаранчевий колір та товщину `10`
#
# - для колонки `c` використайте жовтий колір та товщину `1` і маркер `o`

# %%
plt.figure(figsize=(15,10)) 
sns.set_style("darkgrid")

ax = plt.plot(df['a'], 'r-.')
ax = plt.plot(df['b'], 'tab:orange', linewidth = 10)
ax = plt.plot(df['c'], 'y', linewidth = 1, marker = 'o')

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**
# - і не забудьте про легенду :)

# %%
fig, ax = plt.subplots(3, 1, figsize=(15, 10))

ax[0].plot(df['a'], label = 'Line A')
ax[0].legend(loc = 'lower right')
ax[1].plot(df['b'], label = 'Line B')
ax[1].legend(loc = 'center left')
ax[2].plot(df['c'])

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**
# - використайте томатний колір та відстань між стовбцями 0.5

# %%
fig, ax = plt.subplots(figsize=(15, 8))

#plt.hist(df['a'], width = 5)
ax.vlines(x=df.index, ymin=0, ymax=df.a, color='tomato', alpha=0.5, linewidth=20)

# %% [markdown]
# **Створити візуалізацію, аналогічно рисунку**
# - добавте всі підписи та правильний маркер

# %%
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(18, 8))
ax.plot(df['a'], marker=mpl.markers.CARETUPBASE)
plt.grid(axis='x', alpha=1, linewidth=1)
plt.xticks(np.arange(0,30,1))
ax.set_title('Normal Title')
ax.set_ylabel('Title for Y-Axis', loc='center')
ax.set_xlabel('Title for X-Axis', loc='center', fontsize = 20)
# Out:
# Text(0.5, 0, 'Title for X-Axis')

# %%
# ?ax.set_xlabel
