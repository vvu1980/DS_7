# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(r"C:\Users\VladV\Documents\ОБУЧЕНИЕ\data_arenda.xlsx")

# %%
df.head()
# Out:
#         sku  Price  Square  Rooms  Area_score  ЖК  Первиннежитло  Disttometro  \
# 0  22015935  93333     120      4           4   1              0         0.77
# 1  22020975  80000      75      2           4   1              0         0.59
# 2  21649711  93333      94      3           4   1              0         0.59
# 3  21530695  72000     100      3           2   1              0         0.99
# 4  22093967  53333     101      4           3   1              0         0.46
#
#    time_to_metro
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.dtypes
# Out:
# sku                int64
# Price              int64
# Square             int64
# Rooms              int64
# Area_score         int64
# ЖК                 int64
# Первиннежитло      int64
# Disttometro      float64
# time_to_metro      int64
# dtype: object

# %%
df.describe()
# Out:
#                 sku          Price       Square        Rooms   Area_score  \
# count  3.693000e+03    3693.000000  3693.000000  3693.000000  3693.000000
# mean   2.129216e+07   62652.710263   102.407257     2.626049     3.483347
# std    1.396722e+06   50520.435604    57.466245     1.034687     0.729027
# min    1.117980e+07    7500.000000     4.000000     1.000000     1.000000
# 25%    2.089576e+07   33000.000000    63.000000     2.000000     3.000000
# 50%    2.204137e+07   46667.000000    90.000000     3.000000     4.000000
# 75%    2.212605e+07   77128.000000   125.000000     3.000000     4.000000
# max    2.224159e+07  531915.000000  1000.000000    10.000000     4.000000
#
#                 ЖК  Первиннежитло  Disttometro  time_to_metro
# count  3693.000000    3693.000000  3693.000000    3693.000000
# mean      0.348226       0.058218     3.393729       1.138370
# std       0.476473       0.234187    43.516167       0.391642
# min       0.000000       0.000000     0.020000       1.000000
# 25%       0.000000       0.000000     0.410000       1.000000
# 50%       0.000000       0.000000     0.550000       1.000000
# 75%       1.000000       0.000000     0.770000       1.000000
# max       1.000000       1.000000  1000.000000       3.000000

# %%
fig, ax = plt.subplots(figsize=(15, 15))
pd.plotting.scatter_matrix(df, alpha = 0.5, ax=ax)
# Out:
# <ipython-input-6-2e8317d41774>:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   pd.plotting.scatter_matrix(df, alpha = 0.5, ax=ax)
# array([[<AxesSubplot:xlabel='sku', ylabel='sku'>,
#         <AxesSubplot:xlabel='Price', ylabel='sku'>,
#         <AxesSubplot:xlabel='Square', ylabel='sku'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='sku'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='sku'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='sku'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='sku'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='sku'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='sku'>],
#        [<AxesSubplot:xlabel='sku', ylabel='Price'>,
#         <AxesSubplot:xlabel='Price', ylabel='Price'>,
#         <AxesSubplot:xlabel='Square', ylabel='Price'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='Price'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='Price'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='Price'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='Price'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='Price'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='Price'>],
#        [<AxesSubplot:xlabel='sku', ylabel='Square'>,
#         <AxesSubplot:xlabel='Price', ylabel='Square'>,
#         <AxesSubplot:xlabel='Square', ylabel='Square'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='Square'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='Square'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='Square'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='Square'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='Square'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='Square'>],
#        [<AxesSubplot:xlabel='sku', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='Price', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='Square', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='Rooms'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='Rooms'>],
#        [<AxesSubplot:xlabel='sku', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='Price', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='Square', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='Area_score'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='Area_score'>],
#        [<AxesSubplot:xlabel='sku', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='Price', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='Square', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='ЖК'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='ЖК'>],
#        [<AxesSubplot:xlabel='sku', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='Price', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='Square', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='Первиннежитло'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='Первиннежитло'>],
#        [<AxesSubplot:xlabel='sku', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='Price', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='Square', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='Disttometro'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='Disttometro'>],
#        [<AxesSubplot:xlabel='sku', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='Price', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='Square', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='Rooms', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='Area_score', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='ЖК', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='Первиннежитло', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='Disttometro', ylabel='time_to_metro'>,
#         <AxesSubplot:xlabel='time_to_metro', ylabel='time_to_metro'>]],
#       dtype=object)

# %%
df.corr()
# Out:
#                     sku     Price    Square     Rooms  Area_score        ЖК  \
# sku            1.000000 -0.201236 -0.168727 -0.152956   -0.164915 -0.224260
# Price         -0.201236  1.000000  0.749243  0.527368    0.257936  0.026236
# Square        -0.168727  0.749243  1.000000  0.714677    0.115579 -0.132878
# Rooms         -0.152956  0.527368  0.714677  1.000000    0.082409 -0.108287
# Area_score    -0.164915  0.257936  0.115579  0.082409    1.000000  0.094674
# ЖК            -0.224260  0.026236 -0.132878 -0.108287    0.094674  1.000000
# Первиннежитло -0.022787  0.032268  0.005644  0.026156   -0.026842  0.056148
# Disttometro    0.017383 -0.016376 -0.023254 -0.014780   -0.046173  0.011994
# time_to_metro  0.095522 -0.121230 -0.054338 -0.044055   -0.329171 -0.124745
#
#                Первиннежитло  Disttometro  time_to_metro
# sku                -0.022787     0.017383       0.095522
# Price               0.032268    -0.016376      -0.121230
# Square              0.005644    -0.023254      -0.054338
# Rooms               0.026156    -0.014780      -0.044055
# Area_score         -0.026842    -0.046173      -0.329171
# ЖК                  0.056148     0.011994      -0.124745
# Первиннежитло       1.000000     0.048630       0.018459
# Disttometro         0.048630     1.000000       0.306711
# time_to_metro       0.018459     0.306711       1.000000

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(15, 15))
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(20, 220, n=200), square=True)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.histplot(data = df, x = 'Price', ax=ax)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(15, 5))


sns.distplot(df['Price'], ax=ax)
# Out:
# C:\Users\VladV\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.lmplot(x = 'Square', y = 'Price', data = df)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
reg = LinearRegression()

# %% [markdown]
# ## Все доступные параметры

# %%
X = df[['Square', 'Rooms', 'Area_score', 'ЖК', 'Первиннежитло','Disttometro', 'time_to_metro']]
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  663.41023007, -1015.94563685, 10667.82910924, 11105.41764156,
#         5444.50430326,    24.42059975, -3214.53521413])

# %%
reg.score(X_train, y_train)
# Out:
# 0.5935443259952542

# %%
reg.score(X_test, y_test)
# Out:
# 0.6470765843688464

# %% [markdown]
# ## Площадь, количество комнат, время до метро

# %%
X1 = df[['Square', 'Rooms', 'time_to_metro']]
y1 = df['Price']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.2)

# %%
reg.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([   639.32048622,    200.79245058, -11199.30639404])

# %%
reg.score(X1_train, y1_train)
# Out:
# 0.5745322698982006

# %%
reg.score(X1_test, y1_test)
# Out:
# 0.542996636970642

# %% [markdown]
# ## Площадь и Расстояние до метро

# %%
X2 = df[['Square', 'Disttometro']]
y2 = df['Price']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.2)

# %%
reg.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([671.89002976,   2.50019857])

# %%
reg.score(X2_train, y2_train)
# Out:
# 0.5587844024007176

# %%
reg.score(X2_test, y2_test)
# Out:
# 0.5696428111558736
